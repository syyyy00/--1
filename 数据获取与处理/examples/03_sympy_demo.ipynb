# %%
# ==============================
# 03 符号计算练习
# 推导公式、求导、积分、LaTeX
# ==============================

from symbolic_utils import get_sym, derivative, integral, solve_eq, to_latex

# 定义符号
x = get_sym('x')

# --------------------
# 1. 求导 + 论文公式
# --------------------
f = x**3 + sp.sin(x)
df, latex_df = derivative(f)
print("导函数：", df)
print("论文LaTeX：", latex_df)

# --------------------
# 2. 积分
# --------------------
res, latex_res = integral(x**2 + sp.cos(x))
print("积分结果：", res)

# --------------------
# 3. 解方程
# --------------------
eq = x**2 - 5*x + 6
print("方程解：", solve_eq(eq))

# --------------------
# 4. 转论文公式（神器）
# --------------------
print("函数的论文公式：", to_latex(f))
