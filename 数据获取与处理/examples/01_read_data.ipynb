# %%
# ==============================
# 01 数据读写练习
# 读取、保存、查看数据
# ==============================

from data_io import read_data, save_data
import pandas as pd

# 1. 读取 Excel 文件
df = read_data("测试数据.xlsx", encoding="gbk")

# 2. 查看数据
print("前5行：")
print(df.head())

print("\n列名：")
print(df.columns.tolist())

print("\n数据信息：")
print(df.info())

# 3. 读取 CSV（如果有）
# df = read_data("数据.csv", encoding="gbk")

# 4. 跳过表头（前2行是说明）
# df = read_data("数据.xlsx", skiprows=2, encoding="gbk")

# 5. 读取所有 sheet
# all_sheets = read_data("多sheet.xlsx", sheet_name=None)
# print(all_sheets.keys())

# 6. 保存处理好的数据
save_data(df, "输出结果.xlsx")
print("✅ 保存成功！")
