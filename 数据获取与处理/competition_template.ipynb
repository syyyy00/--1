# %%
# ==============================================
# 电工杯数学建模 · 比赛万能模板
# 一键导入所有工具，直接开始做题
# 作者：你的名字
# ==============================================

# 1. 基础库
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sympy as sp

# 2. 高级计算库
from scipy.optimize import minimize, curve_fit
from scipy.integrate import solve_ivp
from scipy.interpolate import interp1d

# 3. 自建工具箱（核心！）
from data_io import read_data, save_data
from numeric_utils import solve_linear, poly_fit, numerical_integral
from symbolic_utils import derivative, integral, solve_eq, to_latex
from plot_library import plot_lines, scatter_plot, heatmap, plot_3d_surface

# 4. 绘图全局设置（论文级画质）
plt.rcParams['font.sans-serif'] = ['SimHei', 'Heiti SC']
plt.rcParams['axes.unicode_minus'] = False
sns.set_style("whitegrid")
plt.rcParams['figure.dpi'] = 150
plt.rcParams['savefig.dpi'] = 300

print("✅ 所有工具库导入完成！可以直接开始做题！")
# Out:
# ✅ 所有工具库导入完成！可以直接开始做题！
